# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs
r = requests.get ('https://www.se.com/ww/en/about-us/events/')
soup = bs(r.content , 'lxml')
soup

events = soup.find_all(class_="tips-list-item--content")
events
# Out:
# [<div class="tips-list-item--content">
#  <h4>INNOVATION HUB</h4>
#  <p>Visit showroom sites worldwide to discover our latest innovations.</p>
#  <span>See our global hubs</span>
#  </div>, <div class="tips-list-item--content">
#  <h4>INNOVATION DAY</h4>
#  <p>A 1-day innovation event packed with keynotes, strategy talks, and expert learning sessions.</p>
#  </div>, <div class="tips-list-item--content">
#  <h4>INNOVATION TALK</h4>
#  <p>Attend exclusive innovation sessions and webinars with our experts.</p>
#  </div>, <div class="tips-list-item--content">
#  <h4>TRADE SHOWS</h4>
#  <p>Meet our experts at trade shows worldwide and discover our solutions.</p>
#  </div>, <div class="tips-list-item--content">
#  <h4>SPS IPC Drives 2019</h4>
#  <p>November 26 – 28, Nuremberg, Germany</p>
#  <span>Read more</span>
#  </div>, <div class="tips-list-item--content">
#  <h4>CES 2020</h4>
#  <p>January 7 – 10, Las Vegas, US</p>
#  </div>, <div class="tips-list-item--content">
# ...
